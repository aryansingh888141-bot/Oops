# %%
# THEORITICAL  QUESTION

# %%
#Q-1. What is Object oriented programming (OOP)?
''' Object oriented programming (OOp) is a programming paradigm which is used to combine same class
fuctions together to differentiate from other classes's fuction to  make easy for manipulating,
understandable  and reusable. We can approach all method or attributes by creating one object of
the class. OOPs  helps a lot during handling big project'''

# %%
#Q-2. What is a class in OOP ?
''' class is a blueprint / template for the creating object of this class.class binds methods, attributes/
variable/ data. in class level method and data we can access and modify by creating instance/object
for instance method and in class methods we can access directly through class.'''

# %%
#Q-3. What is a object in OOps ?
''' Object is a copy(that hold same property of class object) of class template. By creating object of
class we can find all methods and attributes of class.'''

# %%
#Q-4. What is difference between abstraction and encapsulation?
''' Abstraction is used for hiding the process of running of unnecessary code by using module abstract
base class (as 'abc'). Where as encapsulation is used for avoid the access to every one to protect
unneeded modification by everyone. encapsulation is make three types of code one is public which can
access everyone by using on underscore( ) second is protected which can access internally or who have
given the access for make the code protected we use one underscore(_) and third type of code is private
which no body can access the code without prior knowledge of class name.'''

# %%
#Q-5. What are dunder method in python ?
''' Dunder method is also known as a magic method . Its initialize the class and with help of this
method we can pass multiple arguments at once. without using this method we have to fixed the attribute
and we can get only this attribute. If we want to get other attribute which we have passed in object.
Then  we will not able for that . For this we have to use dunder/magic method.'''

# %%
#Q-6. Explain the concept of inheritance in OOP.
''' In inheritance child class inherit the property from parent class and grand child can inherit
property from parent class and grand parent class also but parent class can,t inherit the property
from child class. child class is powerfull than parent class so by creating object of child class
we can call method of parent class but by creating object of parent class we can,t call the method
of child class '''

# %%
#Q-7. What is polymorphism in OOP?
''' Polymorphism word is consist of two words first is poly which means is many and second is morph
which means forms/state. when one function or method behave differently basis on different - different
argument then it is called polymorphism.
exa- def add(a,b):
        return a+b
   this function will work adder for two int. where as it will work as concatenator for two sting '''

# %%
#Q-8. How is encapsulation achieved in python?
''' In the python for achieving the encapsulation we use underscore(_) with the attribute during
initializing the class. for the accessing the code to everyone we don't use underscore( ) which is
called public code. for giving limited access to code we use one underscore(_) which called protected
code. And the third is  private code which can't be accessed by anyone for protecting any modification
we use double underscore(__).'''

# %%
#Q-9. What is a constructor in python?
''' __init__ is a constructor which is used for initializing the class. it creates the variable.'''

# %%
#Q-10. What is class and static methods in python?
''' class method is a class level method which is bound to the class. for defining the class method
we use first parameter cls. we can access class method directly using classname.classfunction. class
methos is a alternative of intit methos. where as static method is a simple method it does not take any
parameter to define it. for defining the static method we use @staticmethod. for calling the static
method we use classname.staticfunction simply.'''

# %%
#Q-11. What is method overloading in python?
''' Method overloading is a method of defining a class in which we define multiple same name function.
In which some method can be without attribute and some method can be with attribute. all method can
be execute creating one object of class and passing needed argument.last method is overloading of
previous one.this is called method overloading. method overloading happens in same class.
example '''
class student:
  def student(self):
    print("this is first method")
  def student(self,name = ""):
    print("this is second method" , name)
  def student(self,name = "" , age = ""):
    print("this is third method" , name , age)
obj = student()
print(obj.student())
print(obj.student("shubham"))
print(obj.student("shubham" , 20))
# Out:
# this is third method
# None
# this is third method shubham
# None
# this is third method shubham 20
# None

# %%
#Q-12. What is method overriding in OOP?
''' Method overriding can be achieved in one inheritance class . Although child class is more powerful
than parent class so if we difine same function name of parent class and child class and creates the
object of child class then we call the function. method of child class will be executed. this is called
method overriding.'''

# %%
#Q-13. What is a property decorator in python?
''' Property decorator is a inbuilt decorator. it is defined as @property. It allows method to be
accessed as a property.'''

# %%
#Q-14. Why is polymorphism important in oops?
''' Polymorphism importont for its feature as reusability , reusability means a defined function and
method can be used for multiple purpose as per the need. for example '+' does work as addition for
integer and concetator for string.'''

# %%
#Q-15. What is an abstract class in python?
''' abstract base class is a module. which is used for hiding the process of unneccessary
 part of code'''

# %%
#Q-16. What are the advantages of OOP?
''' Oop is helps us in handing big project because in  big project might need to seperate the same
type function as backend function , frontend function and data pipeline. With the help of it we can
easily access and modify the function.'''

# %%
#Q-17. What is the difference between a class variable and an instance variable?
''' class variable is the fix variable and it is passed in the class and out of init method where as
  in the instance vareable we can pass differet values and it is passed inside of init method. class
  variable can be accessed directly while instance variable can be accessed by creating object of the
  class.'''

# %%
#Q-18. What is multiple inheritance in python?
''' When child class inherit the property from multiple parent class is called multiple inheritance.
'''

# %%
#Q-19. Explain the purpose of __str__ and __repr__ method in python.
''' Both are dunder/magic/special method. __str__ is used for giving string representation of the object
and __repr__ is used for giving representation of the object as it is.'''

# %%
#Q-20. What is the significance of the 'super()' function in python?
''' super() is play very important role in oops. It allows child class to access the method of parent
class. With the help of this we can avoid repitation of code and it makes code easily readable
short and clean'''

# %%
#Q-22. What is the difference between @staticmethod and @classmethod in python?
'''  @staticmethod and @classmethod both are decorator we use @staticmethod for defining the static method
and @classmethod for defining the class method.'''

# %%
#Q-23. How does polymorphism work in python with inheritance?
''' Polymorphism does work in inheritance when we make same name function of parent class and child
class. And when we call the function on differet differen object then we find different output.'''

# %%
#Q-25. what is purpose of the __call__ method in python?
'''  __call__ is a special method we call/invoke it when we have need to use object/instance of class
as a function'''

# %%
# PRACTICAL QUESTIONS

# %%
#Q-1. Create a parent class Animal with a method speak() that prints a generic message. Cerate a child
#        class Dog that overrides the speak() method to print "Bark".
class animal:
  def speak(self):
    print("this is generic message")
class dog(animal):
  def speak(self):
    print("bark")
obj = dog()
obj.speak()
# Out:
# bark

# %%
#Q-2. Write a program to create an abstract class shape with a method area(). Drive classess Circle
#     and Rectange from it and implement the area() method in both.
from abc import ABC , abstractmethod
@abstractmethod
class shape(ABC):
  def area(self):
    pass
  def area(self):
    pass
class circle(shape):
  def area(self):
    print("area of circle")
class rectangle(shape):
  def area(self):
    print("area of rectangle")
a = circle()
a.area()
b = rectangle()
b.area()
# Out:
# area of circle
# area of rectangle

# %%
#Q-3. Implement a multi- level inheritance scenario where a class Vehicle has an attribute type Derive a
#     a class Car and further derive a class ElectricCar that adds a battery attribute.
class vehicle:
  def __init__(self,type):
    self.type = type
class car(vehicle):
  def __init__(self,type,name):
    super().__init__(type)
    self.name = name
class electriccar(car):
  def __init__(self,type,name,battery):
    super().__init__(type,name)
    self.battery = battery
obj = electriccar("car","tata","yes")
print(obj.type)
print(obj.name)
print(obj.battery)
# Out:
# car
# tata
# yes

# %%
#Q-4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derved
#     classes Sparrow and Penguin that fly() method.
class bird:
  def fly(self):
    print("this is base class")
class sparrow(bird):
  def fly(self):
    print("this is sparrow")
class penguin(bird):
  def fly(self):
    print("this is penguin")
obj1 = sparrow()
obj2 = penguin()
obj1.fly()
obj2.fly()
# Out:
# this is sparrow
# this is penguin

# %%
#Q-5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attribute
#     balance and methods to deposit, withdraw, and check balance.
class bankaccount:
  def __init__(self,balance):
    self.__balance = balance
  def deposit(self,amount):
    self.__balance += amount
  def withdraw(self,amount):
    self.__balance -= amount
  def checkbalance(self):
    return self.__balance

# %%
#Q-6. Demonstrate runtime polymorphism using a method play() in a base class instrument Derive classes
#     Guitar and Piano that implement their own version of play().
class instrument:
  def play(self):
    print("this is base class")
class guitar(instrument):
  def play(self):
    print("this is guitar")
class piano(instrument):
  def play(self):
    print("this is piano")
obj1 = guitar()
obj2 = piano()
obj1.play()
obj2.play()
# Out:
# this is guitar
# this is piano

# %%
#Q-7. Create a class MathOperation with a class method add_numbers() to add two numbers and a static
#     method subtract_numbers() to subtract two numbers.
class mathoperation:
  @classmethod
  def add_numbers(cls,a,b):
    return a+b
  @staticmethod
  def subtract_numbers(a,b):
    return a-b
obj = mathoperation()
print(obj.add_numbers(2,3))
print(obj.subtract_numbers(2,3))
# Out:
# 5
# -1

# %%
#Q-8. Implement a class Person with a class method to count the total number of persons created.
class person:
  count = 0
  def __init__(self):
    person.count += 1
  @classmethod
  def total_person(cls):
    return person.count
obj1 = person()
obj2 = person()
obj3 = person()
print(person.total_person())
# Out:
# 3

# %%
#Q-9. Write a class function with attributes numerator and denominator. Override the str method to
#     display the fraction as "numerator/demominator".
class fraction:
  def __init__(self,numerator,denominator):
    self.numerator = numerator
    self.denominator = denominator
  def __str__(self):
    return f"{self.numerator}/{self.denominator}"
obj = fraction(2,3)
print(obj)
# Out:
# 2/3

# %%
#Q-10. Demonstrate operator overloading by creating a class Vector and overriiding the add method to
#      add two vectors.
class vector:
  def __init__(self,x,y):
    self.x = x
    self.y = y
  def __add__(self,other):
    return vector(self.x + other.x , self.y + other.y)
  def __str__(self):
    return f"{self.x} {self.y}"
obj1 = vector(1,2)
obj2 = vector(3,4)
obj3 = obj1 + obj2
print(obj3)
# Out:
# 4 6

# %%
#Q-11. Create a class Person with attributes name and age. Add  method greet() that prints
#      "Hello, my name is {name} and I am {age} years old".
class person:
  def __init__(self,name,age):
    self.name = name
    self.age = age
  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")
obj = person("Aryan" , 25)
obj.greet()
# Out:
# Hello, my name is Aryan and I am 25 years old.

# %%
#Q-12. Implement a class Student with attributes name and grades. Create a method average_grade( to)
#      to compute the average of the grades.
class student:
  def __init__(self,name,grades):
    self.name = name
    self.grades = grades
  def average_grade(self):
    return sum(self.grades)/len(self.grades)
obj = student("Aryan" , [90,80,70])
print(obj.average_grade)
# Out:
# <bound method student.average_grade of <__main__.student object at 0x7eaab529d9d0>>

# %%
#Q-13. Create a class Rectangle with methods set_dimensions() to set the demensions and area() to
#       calculate the area.
class Rectangle:
  def set_dimensions(self,length,width):
    self.length = length
    self.width = width
  def area(self):
    return self.length * self.width
obj = Rectangle()
obj.set_dimensions(2,3)
print(obj.area())
# Out:
# 6

# %%
#Q-14. Create a class Employee with a method calculate_salary() that compute the salary based on hours
#       worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class employee:
  def calculate_salary(self,hours,rate):
    return hours * rate
class manager(employee):
  def calculate_salary(self,hours,rate,bonus):
    return hours * rate + bonus
obj = manager()
print(obj.calculate_salary(2,3,4))
# Out:
# 10
