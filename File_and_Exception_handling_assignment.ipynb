# %%
#Q-1. What is the difference between interpreted and compiled languages?
''' Compiled languages uses compiler to convert source code in machine code
before execution of code in one go. while interpreter executes the code line
 by line so it convert one line at a time in machine codeand execute it after
  that second line and so on.Its faster than compiled languages.

# %%
#Q-2. What is exception handling in python?
''' while writing big and robust code there might be chance that some error can
be occure. because of these error fullcode will not be execute to avoid that we
need to handle the exception . so that except error block code rest code can
be execute. this is called exception handling.'''

# %%
#Q-3. What is the purpose of the finally block in exception handling?
''' Finally is the block of code that excute in the final stage of code. it
helps to know that full code have been runor not and also we use finally block
in the last for excute or print something.'''

# %%
#Q-4. What is logging in python?
''' Logging in python means records the process of code and giving the information
 of code stage. So that we can knowproblem stage of code and we can correct the
 code if needed. Since logging record the process  of code in file so we canknow
  the process of code in log file later.'''

# %%
#Q-5. What is the significance of the __del__ method in python?
'''__de__ is a destructor method in python. It runs automatically when object is
about to deleted(i.e., when memory is freed). It is mainly used for cleanup
activites, such as closing files or database connections and realse resources.'''

# %%
#Q-6. What is the difference between import and from import in python?
''' 'import' is used for importing a whole module where as 'fron import' is used
for importing a specific function or class from a module.
i.g.  import math
      math.sqrt()
      from math import sqrt
      sqrt()
import is safer than from import because variable can be overriden. but along
with that from import is faster than import.

# %%
#Q-7. How can you handle multiple exception in python?
''' We can handle multiple exception by using multiple except block together with
 naming right error name.'''

# %%
#Q-8. What is the purpose of the with statement when handling files in python?
''' We use 'with statement' to avoid close the file. with statement automatically
 close the file after use thefile. so that we can use any other mode without any
 hurdle that can be arise due to forget the close the file '''

# %%
#Q-9. What is the difference between multithreading and multiprocessing?
'''Multithreading works in one processor with multiple threads. whole code runs
parallel and share all threads one memory for input and output. Where as
multiprocessing uses multiple processors and uses different memory for each
process. in multiprocessing each process has its own memory space. In both code
execute in parallel.

# %%
#Q-10. What are the advantage of using logging in a program?
''' logging records the process of code in file permanently with the help of this
 we can access problem in the code.And with the help of this we can get informtion
  of code stage like debug, info, warning, error, critical.'''

# %%
#Q-11. What is memory management in Python?
''' Memory management in Python refers to how python alloctes, manages, and frees
memory automatically while our program runs. Python has a bult-in memory manager
that helps to manage memory efficiently. Its allocate memory when we create variables
object, lists, etc and deallocate memory when we delete them.'''

# %%
#Q-12. What are the basic steps involved in exception handling in python?
''' step
    syntax
    try:
       suspicious block of code that can give error
    except:
      this block of code will be excute if any error occure
'''

# %%
#Q-13. Why is memory management important in Python?
''' Memory management is important in Python for the running code fast and
efficiently, use memory efficienly and avoid memory leaks.

# %%
#Q-14.What is the role of try and except in exception handling?
''' In the try block we write the suspicious code which can give error and in the
except block the code which we have execute after the code give error. In the
python execution of code stop after occuring error to avoid that error and
 execute the whole code we use try and except.'''

# %%
#Q-15. How does Python's garbage collection system work?
''' Python garbage collection system is designed to automatically manage memory
by reclaiming unused memory so that developers don't have to manually free it.
And we can use it for other purpose and dev. Its system work based on refference
coutinting method and cycle detection method. When refference increases it add and
when it decreases it decrease the refferences. when refferences becomes 0 it frees
the memory.

# %%
#Q-16.What is the purpose of the else block in exception handling?
''' else block is used to execute the code which is important ofter execution of
 try block code correct. Because in thecase of try block code right code does not
 inter in the except block.

# %%
#Q-17. What are the common logging levals in python?
''' Common logging levels in python are debug, info, warning, error, critical. '''

# %%
#Q-19. What is the important of closing a file in python?
''' Without closing the file we can not access the file in different mode.

# %%
#Q-20. What is the different between file.read() and file.readline() in python?
''' By using file.read() we can read all the content from the file where as
through file.readline() we can readonly one line from the file.'''

# %%
#Q-21. What is the logging module in Python used for?
''' Logging module in python is a inbuld module of python used to record the
process of code. To giving information of deffernt stage of code. It records
the process so we can see the problem in later.

# %%
#Q-22. What is the os module in Python used for in file handling?
''' The os module in Python is a bult-in module that provides a way to interact
with the operating system. In the context of file handling, it is mainly used to
create, remove, rename, and manipulate files and directories.

# %%
#Q-24. How do you raise an exception manually in python?
''' In Python, we can raise an exception manually using the 'raise' keyword.
this allows us to intentionally signal that an error or exception has occured
in our program.
exa:
x = -5
if x < 0:
  raise ValueError("x cannot be negative")

# %%
# PRACTICAL QUESTIONS

# %%
#Q-1. How can you open a file for writing in python and write a string to it?
data = open("file.txt","w")
data.write("This is my first line in the file")
data.close()

# %%
#Q-2. Write a python program to read the contents of a file and print each line.
data = open("file.txt","r")
print(data.read())
data.close()
# Out:
# This is my first line in the file

# %%
#Q-3. How would you handle a class where the file doesn't exist while trying to open it for reading?
try:
  f = open("Aryan.txt","r")
except FileNotFoundError:
  print("File not found")
# Out:
# File not found

# %%
#Q-4. Write a Python script that reads from one file and writes its content to another file.
data = open("file.txt","r")
data1 = open("file1.txt","w")
data1.write(data.read())
data.close()
data1.close()

# %%
#Q-5. How would you catch and handle division by zero error in python?
try:
  a = 10/0
except ZeroDivisionError:
  print("Division by zero error")
# Out:
# Division by zero error

# %%
#Q-6. Write a python program that logs an error message to a log file when a division by zero exception occurs.
import logging
logging.basicConfig(filename="log.txt",level=logging.ERROR)
try:
  a = 10/0
except ZeroDivisionError:
  f = open("log.txt","w")
  f.write("Division by zero error")
  f.close()
s = open("log.txt","r")
print(s.read())
# Out:
# Division by zero error

# %%
#Q-7. How do you log information at different levals(INFO, ERROR, WARNING) in python using the logging moduls?
import logging
logging.basicConfig(filename="log.txt",level=logging.INFO)
logging.info("This is my first line in the file")
logging.basicConfig(filename="log.txt",level=logging.ERROR)
try:
  a = 10/0
except ZeroDivisionError:
  f = open("log.txt","w")
  f.write("Division by zero error")
logging.basicConfig(filename="log.txt",level=logging.WARNING)
logging.warning("This is my first line in the file")
# Out:
# WARNING:root:This is my first line in the file

# %%
#Q-8. Write a program to handle a file opening error using exception handling.
try:
  f = open("Aryan.txt","r")
except FileNotFoundError:
  print("File not found")
# Out:
# File not found

# %%
d = open("file.txt","w")
d.write("This, ")
d.write("is, ")
d.write("my, ")
d.write("first, ")
d.write("line,")
d.close()

# %%
#Q-9. How can you read a file line by line and store its content in a list in python.
data = open("file.txt","r")
l = []
for i in data:
  l.append(i)
print(l)
# Out:
# ['This, is, my, first, line,']

# %%
#Q-10. How can you append data to an existing file in python?
data = open("file.txt","a")
data.write("\nThis is my second line in the file")
data.close()
data = open("file.txt","r")
print(data.read())
# Out:
# This is my second line in the file

# %%
#Q-11. Write a python program that uses a try-except block to handle an error when attempting to access
#        a dictionary key that doesn't exist.
try:
  d = {"a":1,"b":2,"c":3}
  print(d["d"])
except KeyError:
  print("Key not found")
# Out:
# Key not found

# %%
#Q-12. Write a program that demonstrate using multiple except block to handle different types of exception.
try:
  a = 10/0
except ZeroDivisionError:
  print("Division by zero error")
except TypeError:
  print("Type error")
# Out:
# Division by zero error

# %%
#Q-13. How would you check if a file before attempting to read it in python?
import os
if os.path.exists("Aryan.txt"):
  print("file exist")
else:
  print("file not exist")
# Out:
# file not exist

# %%
from pathlib import Path
p = Path("Aryan.txt")
if p.exists():
  print("file exist")
else:
  print("file not exist")
# Out:
# file not exist

# %%
import os
if os.path.isfile("Aryan.txt"):
  print("file exist")
else:
  print("file not exist")
# Out:
# file not exist

# %%
#Q-14. Write a program that uses the logging module to log both information and error messages.
import logging
logging.basicConfig(filename="log.txt",level=logging.INFO)
logging.info("This is logging info")
logging.basicConfig(filename="log.txt",level=logging.ERROR)
logging.error("This is logging error")
# Out:
# ERROR:root:This is logging error

# %%
#Q-15. Write a python program that prints the content of a file and handles the case when the file is empty.
empty_file = open("empty.txt","w")
empty_file.close()
try:
  f = open("empty.txt","r")
except FileNotFoundError:
  print("File is empty")

# %%
#Q-17. Write a python program to create and write a list of numbers to a file, one number per line
lis = open("list.txt","w")
lis.write("1\n2\n3\n4\n5")
lis.close()
lis = open("list.txt","r")
print(lis.read())
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Q-19. Write a program that handles both IndexError and KeyError using a try-except block.
try:
  l = [1,2,3,4,5]
  print(l[6])
except IndexError:
  print("Index error")
try:
  d = {"a":1,"b":2,"c":3}
  print(d["d"])
except KeyError:
  print("Key error")
# Out:
# Index error
# Key error

# %%
#Q-20. How would you open a file and read its contents using a context manager in python?
with open("file.txt","r") as f:
  print(f.read())
# Out:
# This is my first line in the file

# %%
#Q-21. Write a Python program that reads a file and prints the number of occurrences of a specific word.
file = open("file.txt","r")
count = 0
for i in file:
  count += 1
print(count)
# Out:
# 1

# %%
#Q-22. How can you check if a file is empty before attempting to read its contents?
file1 = open("singh.txt","w")
file1.close()
if os.stat("singh.txt").st_size == 0:
  print("File is empty")
else:
  print(file1.read())
# Out:
# File is empty
